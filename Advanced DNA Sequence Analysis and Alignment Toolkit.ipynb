# %% [markdown]
# # Advanced DNA Sequence Analysis and Alignment Toolkit
#
# This notebook demonstrates the tested package implementation in `src/dna_toolkit`. The algorithms live in the package so they can be reused by the CLI, tests, and Python callers without notebook-only drift.

# %% [markdown]
# ## Import the package

# %%
import sys
from pathlib import Path

project_root = Path.cwd()
src_path = project_root / 'src'
if src_path.exists() and str(src_path) not in sys.path:
    sys.path.insert(0, str(src_path))

from dna_toolkit import (
    bwt_transform,
    edit_distance_with_gap_penalties,
    find_exact_matches,
    inverse_bwt,
    smith_waterman,
    smith_waterman_with_compression,
)

# %% [markdown]
# ## Edit distance with separate gap opening and extension costs

# %%
distance = edit_distance_with_gap_penalties(
    'AAAA',
    'AA',
    consecutive_gap_cost=1,
    isolated_gap_cost=3,
)
distance

# %% [markdown]
# ## Local Smith-Waterman alignment with affine gaps

# %%
alignment = smith_waterman('TTACGTAA', 'GGACGTCC')
alignment

# %% [markdown]
# ## Burrows-Wheeler Transform and inverse transform

# %%
transformed, suffix_array = bwt_transform('GATTACA')
recovered = inverse_bwt(transformed)
transformed, suffix_array, recovered

# %% [markdown]
# ## Exact pattern matching with the BWT index

# %%
find_exact_matches('ATATAT', ['ATA', 'TAT', 'GG'])

# %% [markdown]
# ## Compression-aware alignment

# %%
smith_waterman_with_compression('TTACGTAA', 'GGACGTCC')
